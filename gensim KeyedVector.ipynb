# %%
import os
from gensim.models import KeyedVectors

# %%
path = "/home/goncalo/datasets/aclImdb/vectors_aclImdb.txt"

# %%
wv = KeyedVectors.load_word2vec_format(path, binary=False)  # C text format

# %%
vars(wv)
# Out:
# {'vectors': array([[ 1.33400e-03,  1.47300e-03, -1.27700e-03, ..., -4.37000e-04,
#          -5.52000e-04,  1.02400e-03],
#         [-5.03005e-01, -8.99770e-02,  4.16647e-01, ..., -3.89433e-01,
#           6.49819e-01,  8.59740e-02],
#         [-1.78511e-01, -3.48100e-01, -1.88140e-02, ..., -2.47106e-01,
#           4.46574e-01,  8.19020e-02],
#         ...,
#         [ 1.65760e-01, -1.51890e-02,  2.62370e-01, ..., -7.65950e-02,
#           1.53374e-01,  3.27360e-02],
#         [-5.04830e-02,  4.77370e-02, -2.97590e-02, ..., -1.19679e-01,
#           3.11830e-02, -1.23464e-01],
#         [ 1.69330e-02,  3.31350e-02, -1.46721e-01, ..., -2.91123e-01,
#          -2.30000e-03, -3.26370e-02]], dtype=float32),
#  'vocab': {'</s>': <gensim.models.keyedvectors.Vocab at 0x7f83fc957630>,
#   'the': <gensim.models.keyedvectors.Vocab at 0x7f83fc957748>,
#   '.': <gensim.models.keyedvectors.Vocab at 0x7f83fc957780>,
#   ',': <gensim.models.keyedvectors.Vocab at 0x7f83fc9577b8>,
# ...

# %%
len(wv.vocab)
# Out:
# 168994
